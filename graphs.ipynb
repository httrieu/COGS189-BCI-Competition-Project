# %% [markdown]
# ## Subject 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
subject1Kappa = {
    "left vs rest": 0.86574074,
    "right vs rest": 0.74537037,
    "feet vs rest": 0.89814815,
    "tongue vs rest": 0.72685185
}

subject1Accuracy = {
    "left vs rest": 0.93287037,
    "right vs rest": 0.87268519,
    "feet vs rest": 0.94907407,
    "tongue vs rest": 0.86342593
}

mean_kappa_value = 0.809027777777777  # Additional line value
mean_acc = 0.90451389

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CCACSPLDA Motor Imagery Classification Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Shannon Entropy Channel Selection

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.82638889,
    "right vs rest": 0.82407407,
    "feet vs rest": 0.80324074,
    "tongue vs rest": 0.77314815
}

subject1Accuracy = {
    "left vs rest": 0.91319444,
    "right vs rest": 0.91203704,
    "feet vs rest": 0.90162037,
    "tongue vs rest": 0.88657407
}

mean_kappa_value = 0.8067129625  # Additional line value
mean_acc = 0.90335648

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("Shannon Entropy Channel Selection CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### CSP

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.83101852,
    "right vs rest":0.74537037,
    "feet vs rest": 0.6087963,
    "tongue vs rest": 0.70601852
}

subject1Accuracy = {
    "left vs rest": 0.91550926,
    "right vs rest": 0.87268519,
    "feet vs rest": 0.80439815,
    "tongue vs rest": 0.85300926
}

mean_kappa_value = 0.7228009275  # Additional line value
mean_acc = 0.861400465

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ## COMPARISON

# %%
import matplotlib.pyplot as plt

cca = 0.90451389  # Additional line value
csp = 0.861400465
shannon = 0.90335648

# Plot the line graph
plt.figure(figsize=(8, 5))

# Add reference horizontal line
plt.axhline(y=cca, color='g', label="CCACSP Accuracy")
plt.axhline(y=csp, color='m', label="CSP Accuracy")
plt.axhline(y=shannon, color='b', label="Shannon Entropy Accuracy")
plt.autoscale(enable=True)
# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("Accuracy Comparison")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
#plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

cca = 0.8090277778  # Additional line value
csp = 0.7228009275
shannon = 0.8067129625

# Plot the line graph
plt.figure(figsize=(8, 5))

# Add reference horizontal line
plt.axhline(y=cca, color='g', label="CCACSP Kappa")
plt.axhline(y=csp, color='m', label="CSP Kappa")
plt.axhline(y=shannon, color='b', label="Shannon Entropy Kappa")
plt.autoscale(enable=True)
# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("Kappa Comparison")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
#plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Bands

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "(1, 3)": 0.2812500003,
    "(2, 5)": 0.213541665,
    "(4, 7)": 0.262152775,
    "(6, 10)": 0.3854166667,
    "(7, 12)": 0.5549768519,
    "(10, 15)": 0.5653935185,
    "(12, 19)": 0.5868055556,
    "(15, 25)": 0.5601851852,
    "(19, 30)": 0.5219907407,
    "(25, 35)": 0.5613425926,
    "(30, 40)": 0.4016203704
}

subjectAccuracy = {
    "(1, 3)": 0.6406249975,
    "(2, 5)": 0.606770835,
    "(4, 7)": 0.63107639,
    "(6, 10)": 0.6927083333,
    "(7, 12)": 0.7774884259,
    "(10, 15)": 0.7826967593,
    "(12, 19)": 0.7934027778,
    "(15, 25)": 0.7800925926,
    "(19, 30)": 0.7609953704,
    "(25, 35)": 0.7806712963,
    "(30, 40)": 0.7008101852
}

mean_kappa_value = np.mean(list(subjectKappa.values()))  # Additional line value
mean_acc = np.mean(list(subjectAccuracy.values()))

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Filter Bands (Hz)")
plt.ylabel("Value")
plt.title("Filter Bands CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ## Subject 2

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "left vs rest": 0.3287037,
    "right vs rest": 0.25,
    "feet vs rest": 0.50231481,
    "tongue vs rest": 0.47685185
}

subjectAccuracy = {
    "left vs rest": 0.66435185,
    "right vs rest": 0.625,
    "feet vs rest": 0.75115741,
    "tongue vs rest": 0.73842593
}

mean_kappa_value = 0.389467592592592  # Additional line value
mean_acc = 0.6947337975

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CCACSPLDA Motor Imagery Classification Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Shannon Entropy Channel Selection

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.37037037,
    "right vs rest": 0.28009259,
    "feet vs rest": 0.73842593,
    "tongue vs rest": 0.44907407
}

subject1Accuracy = {
    "left vs rest": 0.68518519,
    "right vs rest": 0.6400463,
    "feet vs rest": 0.86921296,
    "tongue vs rest": 0.72453704
}

mean_kappa_value = 0.45949074074074  # Additional line value
mean_acc = 0.7297453725

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("Shannon Entropy Channel Selection CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### CSP

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.30324074,
    "right vs rest": 0.36111111,
    "feet vs rest": 0.6712963,
    "tongue vs rest": 0.58564815
}

subject1Accuracy = {
    "left vs rest": 0.65162037,
    "right vs rest": 0.68055556,
    "feet vs rest": 0.83564815,
    "tongue vs rest": 0.79282407
}

mean_kappa_value = 0.480324075  # Additional line value
mean_acc = 0.7401620375

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Bands

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "(1, 3)": 0.07696759203,
    "(2, 5)": 0.094328705,
    "(4, 7)": 0.050925925,
    "(6, 10)": 0.05613425926,
    "(7, 12)": 0.1487268519,
    "(10, 15)": 0.1579861111,
    "(12, 19)": 0.3211805556,
    "(15, 25)": 0.4045138889,
    "(19, 30)": 0.2592592593,
    "(25, 35)": 0.2748842593,
    "(30, 40)": 0.1770833333
}

subjectAccuracy = {
    "(1, 3)": 0.5384837975,
    "(2, 5)": 0.54716435,
    "(4, 7)": 0.5254629625,
    "(6, 10)": 0.5280671296,
    "(7, 12)": 0.5743634259,
    "(10, 15)": 0.5789930556,
    "(12, 19)": 0.6605902778,
    "(15, 25)": 0.7022569444,
    "(19, 30)": 0.6296296296,
    "(25, 35)": 0.6374421296,
    "(30, 40)": 0.5885416667
}

mean_kappa_value = np.mean(list(subjectKappa.values()))  # Additional line value
mean_acc = np.mean(list(subjectAccuracy.values()))

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Filter Bands (Hz)")
plt.ylabel("Value")
plt.title("Filter Bands CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ## Subject 3

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "left vs rest": 0.79166667,
    "right vs rest": 0.89583333,
    "feet vs rest": 0.63888889,
    "tongue vs rest": 0.8287037
}

subjectAccuracy = {
    "left vs rest": 0.89583333,
    "right vs rest": 0.94791667,
    "feet vs rest": 0.81944444,
    "tongue vs rest": 0.91435185
}

mean_kappa_value = 0.788773148148148  # Additional line value
mean_acc = 0.8943865725

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CCACSPLDA Motor Imagery Classification Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Shannon Entropy Channel Selection

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.83796296,
    "right vs rest": 0.97685185,
    "feet vs rest": 0.49305556,
    "tongue vs rest": 0.74305556
}

subject1Accuracy = {
    "left vs rest": 0.91898148,
    "right vs rest": 0.98842593,
    "feet vs rest": 0.74652778,
    "tongue vs rest": 0.87152778
}

mean_kappa_value = 0.762731481481481  # Additional line value
mean_acc = 0.8813657425

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("Shannon Entropy Channel Selection CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### CSP

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.68287037,
    "right vs rest": 0.90509259,
    "feet vs rest": 0.55555556,
    "tongue vs rest": 0.80092593
}

subject1Accuracy = {
    "left vs rest": 0.84143519,
    "right vs rest": 0.9525463,
    "feet vs rest": 0.77777778,
    "tongue vs rest": 0.90046296
}

mean_kappa_value = 0.7361111125  # Additional line value
mean_acc = 0.8680555575

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Bands

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "(1, 3)": 0.2413194445,
    "(2, 5)": 0.2528935175,
    "(4, 7)": 0.2644675925,
    "(6, 10)": 0.4670138889,
    "(7, 12)": 0.6221064815,
    "(10, 15)": 0.6082175926,
    "(12, 19)": 0.6128472222,
    "(15, 25)": 0.4450231481,
    "(19, 30)": 0.3940972222,
    "(25, 35)": 0.2962962963,
    "(30, 40)": 0.2164351852
}

subjectAccuracy = {
    "(1, 3)": 0.62065972,
    "(2, 5)": 0.62644676,
    "(4, 7)": 0.632233795,
    "(6, 10)": 0.7335069444,
    "(7, 12)": 0.8110532407,
    "(10, 15)": 0.8041087963,
    "(12, 19)": 0.8064236111,
    "(15, 25)": 0.7225115741,
    "(19, 30)": 0.6970486111,
    "(25, 35)": 0.6481481481,
    "(30, 40)": 0.6082175926
}

mean_kappa_value = np.mean(list(subjectKappa.values()))  # Additional line value
mean_acc = np.mean(list(subjectAccuracy.values()))

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Filter Bands (Hz)")
plt.ylabel("Value")
plt.title("Filter Bands CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ## Subject 5

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "left vs rest": 0.06712963,
    "right vs rest": 0.37268519,
    "feet vs rest": 0.15740741,
    "tongue vs rest": 0.38888889
}

subjectAccuracy = {
    "left vs rest": 0.53356481,
    "right vs rest": 0.68634259,
    "feet vs rest": 0.5787037,
    "tongue vs rest": 0.69444444
}

mean_kappa_value = 0.246527777777777  # Additional line value
mean_acc = 0.623263885

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CCACSPLDA Motor Imagery Classification Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Shannon Entropy Channel Selection

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.10416667,
    "right vs rest": 0.61342593,
    "feet vs rest": 0.09722222,
    "tongue vs rest": 0.47916667
}

subject1Accuracy = {
    "left vs rest": 0.55208333,
    "right vs rest": 0.80671296,
    "feet vs rest": 0.54861111,
    "tongue vs rest": 0.73958333
}

mean_kappa_value = 0.32349537037037  # Additional line value
mean_acc = 0.6617476825

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("Shannon Entropy Channel Selection CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### CSP

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.34027778,
    "right vs rest": 0.50694444,
    "feet vs rest": 0.18518519,
    "tongue vs rest": 0.38657407
}

subject1Accuracy = {
    "left vs rest": 0.67013889,
    "right vs rest": 0.75347222,
    "feet vs rest": 0.59259259,
    "tongue vs rest": 0.69328704
}

mean_kappa_value = 0.35474537  # Additional line value
mean_acc = 0.677372685

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Bands

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "(1, 3)": 0.1145833335,
    "(2, 5)": 0.086805555,
    "(4, 7)": 0.17824074,
    "(6, 10)": 0.1284722222,
    "(7, 12)": 0.1030092593,
    "(10, 15)": 0.03645833333,
    "(12, 19)": 0.09953703704,
    "(15, 25)": 0.1018518519,
    "(19, 30)": 0.1516203704,
    "(25, 35)": 0.1770833333,
    "(30, 40)": 0.1684027778
}

subjectAccuracy = {
    "(1, 3)": 0.5572916675,
    "(2, 5)": 0.5434027775,
    "(4, 7)": 0.5891203725,
    "(6, 10)": 0.5642361111,
    "(7, 12)": 0.5515046296,
    "(10, 15)": 0.5182291667,
    "(12, 19)": 0.5497685185,
    "(15, 25)": 0.5509259259,
    "(19, 30)": 0.5758101852,
    "(25, 35)": 0.5885416667,
    "(30, 40)": 0.5842013889
}

mean_kappa_value = np.mean(list(subjectKappa.values()))  # Additional line value
mean_acc = np.mean(list(subjectAccuracy.values()))

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Filter Bands (Hz)")
plt.ylabel("Value")
plt.title("Filter Bands CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ## Subject 6

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "left vs rest": 0.25231481,
    "right vs rest": 0.34027778,
    "feet vs rest": 0.37962963,
    "tongue vs rest": 0.33333333
}

subjectAccuracy = {
    "left vs rest": 0.62615741,
    "right vs rest": 0.67013889,
    "feet vs rest": 0.68981481,
    "tongue vs rest": 0.66666667
}

mean_kappa_value = 0.326388888888888  # Additional line value
mean_acc = 0.663194445

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CCACSPLDA Motor Imagery Classification Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Shannon Entropy Channel Selection

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.47685185,
    "right vs rest": 0.5,
    "feet vs rest": 0.5462963,
    "tongue vs rest": 0.3912037
}

subject1Accuracy = {
    "left vs rest": 0.73842593,
    "right vs rest": 0.75,
    "feet vs rest": 0.77314815,
    "tongue vs rest": 0.69560185
}

mean_kappa_value = 0.478587962962962  # Additional line value
mean_acc = 0.7392939825

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("Shannon Entropy Channel Selection CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### CSP

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.34722222,
    "right vs rest": 0.34259259,
    "feet vs rest": 0.4537037,
    "tongue vs rest": 0.21527778
}

subject1Accuracy = {
    "left vs rest": 0.67361111,
    "right vs rest": 0.6712963,
    "feet vs rest": 0.72685185,
    "tongue vs rest": 0.60763889
}

mean_kappa_value = 0.3396990725  # Additional line value
mean_acc = 0.6698495375

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Bands

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "(1, 3)": 0.052083335,
    "(2, 5)": 0.0202546275,
    "(4, 7)": 0.1111111125,
    "(6, 10)": 0.1678240741,
    "(7, 12)": 0.1921296296,
    "(10, 15)": 0.2546296296,
    "(12, 19)": 0.2106481481,
    "(15, 25)": 0.1707175926,
    "(19, 30)": 0.1498842593,
    "(25, 35)": 0.1371527778,
    "(30, 40)": 0.08738425926
}

subjectAccuracy = {
    "(1, 3)": 0.526041665,
    "(2, 5)": 0.5101273175,
    "(4, 7)": 0.555555555,
    "(6, 10)": 0.583912037,
    "(7, 12)": 0.5960648148,
    "(10, 15)": 0.6273148148,
    "(12, 19)": 0.6053240741,
    "(15, 25)": 0.5853587963,
    "(19, 30)": 0.5749421296,
    "(25, 35)": 0.5685763889,
    "(30, 40)": 0.5436921296
}

mean_kappa_value = np.mean(list(subjectKappa.values()))  # Additional line value
mean_acc = np.mean(list(subjectAccuracy.values()))

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Filter Bands (Hz)")
plt.ylabel("Value")
plt.title("Filter Bands CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ## Subject 7

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "left vs rest": 0.69675926,
    "right vs rest": 0.81944444,
    "feet vs rest": 0.79398148,
    "tongue vs rest": 0.6412037
}

subjectAccuracy = {
    "left vs rest": 0.84837963,
    "right vs rest": 0.90972222,
    "feet vs rest": 0.89699074,
    "tongue vs rest": 0.82060185
}

mean_kappa_value = 0.737847222222222  # Additional line value
mean_acc = 0.86892361

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CCACSPLDA Motor Imagery Classification Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Shannon Entropy Channel Selection

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.78009259,
    "right vs rest": 0.83101852,
    "feet vs rest": 0.79861111,
    "tongue vs rest": 0.8125
}

subject1Accuracy = {
    "left vs rest": 0.8900463,
    "right vs rest": 0.91550926,
    "feet vs rest": 0.89930556,
    "tongue vs rest": 0.90625
}

mean_kappa_value = 0.805555555555555  # Additional line value
mean_acc = 0.90277778

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("Shannon Entropy Channel Selection CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### CSP

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.73842593,
    "right vs rest": 0.87731481,
    "feet vs rest": 0.6875,
    "tongue vs rest": 0.83101852
}

subject1Accuracy = {
    "left vs rest": 0.86921296,
    "right vs rest": 0.93865741,
    "feet vs rest": 0.84375,
    "tongue vs rest": 0.91550926 
}

mean_kappa_value = 0.783564815  # Additional line value
mean_acc = 0.8917824075

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Bands

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "(1, 3)": 0.313078705,
    "(2, 5)": 0.4027777775,
    "(4, 7)": 0.48900463,
    "(6, 10)": 0.3304398148,
    "(7, 12)": 0.333912037,
    "(10, 15)": 0.5127314815,
    "(12, 19)": 0.4872685185,
    "(15, 25)": 0.5966435185,
    "(19, 30)": 0.578125,
    "(25, 35)": 0.5810185185,
    "(30, 40)": 0.3454861111
}

subjectAccuracy = {
    "(1, 3)": 0.65653935,
    "(2, 5)": 0.70138889,
    "(4, 7)": 0.744502315,
    "(6, 10)": 0.6652199074,
    "(7, 12)": 0.6669560185,
    "(10, 15)": 0.7563657407,
    "(12, 19)": 0.7436342593,
    "(15, 25)": 0.7983217593,
    "(19, 30)": 0.7890625,
    "(25, 35)": 0.7905092593,
    "(30, 40)": 0.6727430556
}

mean_kappa_value = np.mean(list(subjectKappa.values()))  # Additional line value
mean_acc = np.mean(list(subjectAccuracy.values()))

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Filter Bands (Hz)")
plt.ylabel("Value")
plt.title("Filter Bands CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ## Subject 8

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "left vs rest": 0.75231481,
    "right vs rest": 0.77546296,
    "feet vs rest": 0.57638889,
    "tongue vs rest": 0.44444444
}

subjectAccuracy = {
    "left vs rest": 0.87615741,
    "right vs rest": 0.88773148,
    "feet vs rest": 0.78819444,
    "tongue vs rest": 0.72222222
}

mean_kappa_value = 0.637152777777777  # Additional line value
mean_acc = 0.8185763875

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CCACSPLDA Motor Imagery Classification Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Shannon Entropy Channel Selection

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.875,
    "right vs rest": 0.64351852,
    "feet vs rest": 0.14583333,
    "tongue vs rest": 0.35185185
}

subject1Accuracy = {
    "left vs rest": 0.9375,
    "right vs rest": 0.82175926,
    "feet vs rest": 0.57291667,
    "tongue vs rest": 0.67592593
}

mean_kappa_value = 0.504050925925925  # Additional line value
mean_acc = 0.752025465

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("Shannon Entropy Channel Selection CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### CSP

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.82175926,
    "right vs rest": 0.77083333,
    "feet vs rest": 0.5162037,
    "tongue vs rest": 0.44444444
}

subject1Accuracy = {
    "left vs rest": 0.91087963,
    "right vs rest": 0.88541667,
    "feet vs rest": 0.75810185,
    "tongue vs rest": 0.72222222
}

mean_kappa_value = 0.6383101825  # Additional line value
mean_acc = 0.8191550925

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Bands

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "(1, 3)": 0.2112268498,
    "(2, 5)": 0.2609953725,
    "(4, 7)": 0.1961805575,
    "(6, 10)": 0.5798611111,
    "(7, 12)": 0.6412037037,
    "(10, 15)": 0.5625,
    "(12, 19)": 0.412037037,
    "(15, 25)": 0.3258101852,
    "(19, 30)": 0.3078703704,
    "(25, 35)": 0.1475694444,
    "(30, 40)": 0.150462963
}

subjectAccuracy = {
    "(1, 3)": 0.6056134275,
    "(2, 5)": 0.630497685,
    "(4, 7)": 0.5980902775,
    "(6, 10)": 0.7899305556,
    "(7, 12)": 0.8206018519,
    "(10, 15)": 0.78125,
    "(12, 19)": 0.7060185185,
    "(15, 25)": 0.6629050926,
    "(19, 30)": 0.6539351852,
    "(25, 35)": 0.5737847222,
    "(30, 40)": 0.5752314815
}

mean_kappa_value = np.mean(list(subjectKappa.values()))  # Additional line value
mean_acc = np.mean(list(subjectAccuracy.values()))

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Filter Bands (Hz)")
plt.ylabel("Value")
plt.title("Filter Bands CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ## Subject 9

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "left vs rest": 0.90046296,
    "right vs rest": 0.3125,
    "feet vs rest": 0.42824074,
    "tongue vs rest": 0.8125
}

subjectAccuracy = {
    "left vs rest": 0.95023148,
    "right vs rest": 0.65625,
    "feet vs rest": 0.71412037,
    "tongue vs rest": 0.90625
}

mean_kappa_value = 0.613425925925926  # Additional line value
mean_acc = 0.8067129625

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CCACSPLDA Motor Imagery Classification Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Shannon Entropy Channel Selection

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.93287037,
    "right vs rest": 0.52777778,
    "feet vs rest": 0.82175926,
    "tongue vs rest": 0.93055556
}

subject1Accuracy = {
    "left vs rest": 0.96643519,
    "right vs rest": 0.76388889,
    "feet vs rest": 0.91087963,
    "tongue vs rest": 0.96527778
}

mean_kappa_value = 0.80324074074074  # Additional line value
mean_acc = 0.9016203725

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("Shannon Entropy Channel Selection CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### CSP

# %%
import matplotlib.pyplot as plt

# Data
subject1Kappa = {
    "left vs rest": 0.96527778,
    "right vs rest": 0.17592593,
    "feet vs rest": 0.65277778,
    "tongue vs rest": 0.86574074
}

subject1Accuracy = {
    "left vs rest": 0.98263889,
    "right vs rest": 0.58796296,
    "feet vs rest": 0.82638889,
    "tongue vs rest": 0.93287037
}

mean_kappa_value = 0.6649305575  # Additional line value
mean_acc = 0.8324652775

# Extract keys and values
subject1labels = list(subject1Kappa.keys())  # x-axis labels
subject1values = list(subject1Kappa.values())  # y-axis values
subject1acclabels = list(subject1Accuracy.keys())  # x-axis labels
subject1accvalues = list(subject1Accuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subject1labels, subject1values, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subject1acclabels, subject1accvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Comparison")
plt.ylabel("Value")
plt.title("CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()

# %% [markdown]
# ### Bands

# %%
import matplotlib.pyplot as plt

# Data
subjectKappa = {
    "(1, 3)": 0.3061342563,
    "(2, 5)": 0.249421295,
    "(4, 7)": 0.2662037025,
    "(6, 10)": 0.5,
    "(7, 12)": 0.5144675926,
    "(10, 15)": 0.5949074074,
    "(12, 19)": 0.5318287037,
    "(15, 25)": 0.5532407407,
    "(19, 30)": 0.5538194444,
    "(25, 35)": 0.3923611111,
    "(30, 40)": 0.5034722222
}

subjectAccuracy = {
    "(1, 3)": 0.65306713,
    "(2, 5)": 0.6247106475,
    "(4, 7)": 0.6331018525,
    "(6, 10)": 0.75,
    "(7, 12)": 0.7572337963,
    "(10, 15)": 0.7974537037,
    "(12, 19)": 0.7659143519,
    "(15, 25)": 0.7766203704,
    "(19, 30)": 0.7769097222,
    "(25, 35)": 0.6961805556,
    "(30, 40)": 0.7517361111
}

mean_kappa_value = np.mean(list(subjectKappa.values()))  # Additional line value
mean_acc = np.mean(list(subjectAccuracy.values()))

# Extract keys and values
subjectlabels = list(subjectKappa.keys())  # x-axis labels
subjectvalues = list(subjectKappa.values())  # y-axis values
subjectacclabels = list(subjectAccuracy.keys())  # x-axis labels
subjectaccvalues = list(subjectAccuracy.values())  # y-axis values

# Plot the line graph
plt.figure(figsize=(8, 5))
plt.plot(subjectlabels, subjectvalues, marker='o', linestyle='-', color='b', label="Kappa")
plt.plot(subjectacclabels, subjectaccvalues, marker='s', linestyle='-', color='g', label="Accuracy")

# Add reference horizontal line
plt.axhline(y=mean_kappa_value, color='r', linestyle='--', label="Mean Kappa")
plt.axhline(y=mean_acc, color='m', linestyle='--', label="Mean Accuracy")

# Formatting
plt.xlabel("Filter Bands (Hz)")
plt.ylabel("Value")
plt.title("Filter Bands CSPLDA Kappa and Accuracy")
plt.ylim(0, 1)  # Adjust based on data range
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xticks(rotation=15)  # Rotate x labels for better visibility

# Show the plot
plt.show()
